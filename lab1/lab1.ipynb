# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2

img = cv2.imread("./test.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.title("Irokez Dual")
plt.imshow(img)
plt.show()
